# %% [markdown]
# ### Importing the libraries:

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ### Importing the training data:

# %%
train_data = pd.read_csv("SalaryData_Train(1).csv") 
train_data
# Out:
#        age          workclass  ...          native  Salary
# 0       39          State-gov  ...   United-States   <=50K
# 1       50   Self-emp-not-inc  ...   United-States   <=50K
# 2       38            Private  ...   United-States   <=50K
# 3       53            Private  ...   United-States   <=50K
# 4       28            Private  ...            Cuba   <=50K
# ...    ...                ...  ...             ...     ...
# 30156   27            Private  ...   United-States   <=50K
# 30157   40            Private  ...   United-States    >50K
# 30158   58            Private  ...   United-States   <=50K
# 30159   22            Private  ...   United-States   <=50K
# 30160   52       Self-emp-inc  ...   United-States    >50K
#
# [30161 rows x 14 columns]

# %% [markdown]
# ### Importing the testing data:

# %%
test_data = pd.read_csv("SalaryData_Test(1).csv")
test_data
# Out:
#        age      workclass      education  ...  hoursperweek          native  Salary
# 0       25        Private           11th  ...            40   United-States   <=50K
# 1       38        Private        HS-grad  ...            50   United-States   <=50K
# 2       28      Local-gov     Assoc-acdm  ...            40   United-States    >50K
# 3       44        Private   Some-college  ...            40   United-States    >50K
# 4       34        Private           10th  ...            30   United-States   <=50K
# ...    ...            ...            ...  ...           ...             ...     ...
# 15055   33        Private      Bachelors  ...            40   United-States   <=50K
# 15056   39        Private      Bachelors  ...            36   United-States   <=50K
# 15057   38        Private      Bachelors  ...            50   United-States   <=50K
# 15058   44        Private      Bachelors  ...            40   United-States   <=50K
# 15059   35   Self-emp-inc      Bachelors  ...            60   United-States    >50K
#
# [15060 rows x 14 columns]

# %% [markdown]
# ### Adding both the train and test data to see the entire data:
# ##### This wont be used in the building of the model

# %%
data = pd.concat([train_data, test_data])
data
# Out:
#        age          workclass   education  ...  hoursperweek          native  Salary
# 0       39          State-gov   Bachelors  ...            40   United-States   <=50K
# 1       50   Self-emp-not-inc   Bachelors  ...            13   United-States   <=50K
# 2       38            Private     HS-grad  ...            40   United-States   <=50K
# 3       53            Private        11th  ...            40   United-States   <=50K
# 4       28            Private   Bachelors  ...            40            Cuba   <=50K
# ...    ...                ...         ...  ...           ...             ...     ...
# 15055   33            Private   Bachelors  ...            40   United-States   <=50K
# 15056   39            Private   Bachelors  ...            36   United-States   <=50K
# 15057   38            Private   Bachelors  ...            50   United-States   <=50K
# 15058   44            Private   Bachelors  ...            40   United-States   <=50K
# 15059   35       Self-emp-inc   Bachelors  ...            60   United-States    >50K
#
# [45221 rows x 14 columns]

# %% [markdown]
# ### EDA and Preproccesing the data:

# %%
# Categorial data
cat_data = data.select_dtypes(exclude='number')
cat_data
# Out:
#                workclass   education  ...          native  Salary
# 0              State-gov   Bachelors  ...   United-States   <=50K
# 1       Self-emp-not-inc   Bachelors  ...   United-States   <=50K
# 2                Private     HS-grad  ...   United-States   <=50K
# 3                Private        11th  ...   United-States   <=50K
# 4                Private   Bachelors  ...            Cuba   <=50K
# ...                  ...         ...  ...             ...     ...
# 15055            Private   Bachelors  ...   United-States   <=50K
# 15056            Private   Bachelors  ...   United-States   <=50K
# 15057            Private   Bachelors  ...   United-States   <=50K
# 15058            Private   Bachelors  ...   United-States   <=50K
# 15059       Self-emp-inc   Bachelors  ...   United-States    >50K
#
# [45221 rows x 9 columns]

# %%
# Numerical data
num_data = data.select_dtypes(include='number')
num_data
# Out:
#        age  educationno  capitalgain  capitalloss  hoursperweek
# 0       39           13         2174            0            40
# 1       50           13            0            0            13
# 2       38            9            0            0            40
# 3       53            7            0            0            40
# 4       28           13            0            0            40
# ...    ...          ...          ...          ...           ...
# 15055   33           13            0            0            40
# 15056   39           13            0            0            36
# 15057   38           13            0            0            50
# 15058   44           13         5455            0            40
# 15059   35           13            0            0            60
#
# [45221 rows x 5 columns]

# %%
num_data.describe().T
# Out:
#                 count         mean          std  ...   50%   75%      max
# age           45221.0    38.548086    13.217981  ...  37.0  47.0     90.0
# educationno   45221.0    10.118463     2.552909  ...  10.0  13.0     16.0
# capitalgain   45221.0  1101.454700  7506.511295  ...   0.0   0.0  99999.0
# capitalloss   45221.0    88.548617   404.838249  ...   0.0   0.0   4356.0
# hoursperweek  45221.0    40.938038    12.007640  ...  40.0  45.0     99.0
#
# [5 rows x 8 columns]

# %%
# Checking how many values are there in categorical data
for col in cat_data:
    print(col, "\n")
    print(cat_data[col].value_counts())
    print("_____________","\n\n")
# Out:
# workclass
#
#  Private             33306
#  Self-emp-not-inc     3796
#  Local-gov            3100
#  State-gov            1946
#  Self-emp-inc         1646
#  Federal-gov          1406
#  Without-pay            21
# Name: workclass, dtype: int64
# _____________
#
#
# education
#
#  HS-grad         14783
#  Some-college     9898
#  Bachelors        7570
#  Masters          2514
#  Assoc-voc        1959
#  11th             1619
#  Assoc-acdm       1507
#  10th             1223
#  7th-8th           823
#  Prof-school       785
#  9th               676
#  12th              577
#  Doctorate         544
#  5th-6th           449
#  1st-4th           222
#  Preschool          72
# Name: education, dtype: int64
# _____________
#
#
# maritalstatus
#
#  Married-civ-spouse       21055
#  Never-married            14597
#  Divorced                  6297
#  Separated                 1411
#  Widowed                   1277
#  Married-spouse-absent      552
#  Married-AF-spouse           32
# Name: maritalstatus, dtype: int64
# _____________
#
#
# occupation
#
#  Craft-repair         6020
#  Prof-specialty       6008
#  Exec-managerial      5984
#  Adm-clerical         5540
#  Sales                5408
#  Other-service        4808
#  Machine-op-inspct    2969
#  Transport-moving     2316
#  Handlers-cleaners    2046
#  Farming-fishing      1480
#  Tech-support         1420
#  Protective-serv       976
#  Priv-house-serv       232
#  Armed-Forces           14
# Name: occupation, dtype: int64
# _____________
#
#
# relationship
#
#  Husband           18666
#  Not-in-family     11702
#  Own-child          6626
#  Unmarried          4788
#  Wife               2091
#  Other-relative     1348
# Name: relationship, dtype: int64
# _____________
#
#
# race
#
#  White                 38902
#  Black                  4228
#  Asian-Pac-Islander     1303
#  Amer-Indian-Eskimo      435
#  Other                   353
# Name: race, dtype: int64
# _____________
#
#
# sex
#
#  Male      30527
#  Female    14694
# Name: sex, dtype: int64
# _____________
#
#
# native
#
#  United-States                 41292
#  Mexico                          903
#  Philippines                     283
#  Germany                         193
#  Puerto-Rico                     175
#  Canada                          163
#  India                           147
#  El-Salvador                     147
#  Cuba                            133
#  England                         119
#  China                           113
#  Jamaica                         103
#  South                           101
#  Italy                           100
#  Dominican-Republic               97
#  Japan                            89
#  Guatemala                        86
#  Vietnam                          83
#  Columbia                         82
#  Poland                           81
#  Haiti                            69
#  Portugal                         62
#  Iran                             56
#  Taiwan                           55
#  Greece                           49
#  Nicaragua                        48
#  Peru                             45
#  Ecuador                          43
#  Ireland                          36
#  France                           36
#  Thailand                         29
#  Hong                             28
#  Cambodia                         26
#  Trinadad&Tobago                  26
#  Yugoslavia                       23
#  Outlying-US(Guam-USVI-etc)       22
#  Laos                             21
#  Scotland                         20
#  Honduras                         19
#  Hungary                          18
# Name: native, dtype: int64
# _____________
#
#
# Salary
#
#  <=50K    34013
#  >50K     11208
# Name: Salary, dtype: int64
# _____________

# %%
# One-Hot encoding the required columns:
cat_columns = list(cat_data.columns)
cat_columns.remove("sex")
cat_columns.remove("Salary")
cat_columns.remove("education")
train_data = pd.get_dummies(train_data, columns=cat_columns, drop_first=True)
test_data = pd.get_dummies(test_data, columns=cat_columns, drop_first=True)

# %%
# removing the education column, as the information is retained in the educationno column:
train_data = train_data.drop(labels="education", axis=1)
test_data = test_data.drop(labels="education", axis=1)
train_data
# Out:
#        age  educationno  ... native_ Vietnam  native_ Yugoslavia
# 0       39           13  ...               0                   0
# 1       50           13  ...               0                   0
# 2       38            9  ...               0                   0
# 3       53            7  ...               0                   0
# 4       28           13  ...               0                   0
# ...    ...          ...  ...             ...                 ...
# 30156   27           12  ...               0                   0
# 30157   40            9  ...               0                   0
# 30158   58            9  ...               0                   0
# 30159   22            9  ...               0                   0
# 30160   52            9  ...               0                   0
#
# [30161 rows x 80 columns]

# %%
# Label encoding the required columns:
label_encoder = preprocessing.LabelEncoder()
train_data["Salary"]= label_encoder.fit_transform(train_data["Salary"])
test_data["Salary"]= label_encoder.fit_transform(test_data["Salary"])
train_data["sex"]= label_encoder.fit_transform(train_data["sex"])
test_data["sex"]= label_encoder.fit_transform(test_data["sex"])

# %%
# Checking if all the information is in numerics
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 80 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   30161 non-null  int64
#  1   educationno                           30161 non-null  int64
#  2   sex                                   30161 non-null  int64
#  3   capitalgain                           30161 non-null  int64
#  4   capitalloss                           30161 non-null  int64
#  5   hoursperweek                          30161 non-null  int64
#  6   Salary                                30161 non-null  int64
#  7   workclass_ Local-gov                  30161 non-null  uint8
#  8   workclass_ Private                    30161 non-null  uint8
#  9   workclass_ Self-emp-inc               30161 non-null  uint8
#  10  workclass_ Self-emp-not-inc           30161 non-null  uint8
#  11  workclass_ State-gov                  30161 non-null  uint8
#  12  workclass_ Without-pay                30161 non-null  uint8
#  13  maritalstatus_ Married-AF-spouse      30161 non-null  uint8
#  14  maritalstatus_ Married-civ-spouse     30161 non-null  uint8
#  15  maritalstatus_ Married-spouse-absent  30161 non-null  uint8
#  16  maritalstatus_ Never-married          30161 non-null  uint8
#  17  maritalstatus_ Separated              30161 non-null  uint8
#  18  maritalstatus_ Widowed                30161 non-null  uint8
#  19  occupation_ Armed-Forces              30161 non-null  uint8
#  20  occupation_ Craft-repair              30161 non-null  uint8
#  21  occupation_ Exec-managerial           30161 non-null  uint8
#  22  occupation_ Farming-fishing           30161 non-null  uint8
#  23  occupation_ Handlers-cleaners         30161 non-null  uint8
#  24  occupation_ Machine-op-inspct         30161 non-null  uint8
#  25  occupation_ Other-service             30161 non-null  uint8
#  26  occupation_ Priv-house-serv           30161 non-null  uint8
#  27  occupation_ Prof-specialty            30161 non-null  uint8
#  28  occupation_ Protective-serv           30161 non-null  uint8
#  29  occupation_ Sales                     30161 non-null  uint8
#  30  occupation_ Tech-support              30161 non-null  uint8
#  31  occupation_ Transport-moving          30161 non-null  uint8
#  32  relationship_ Not-in-family           30161 non-null  uint8
#  33  relationship_ Other-relative          30161 non-null  uint8
#  34  relationship_ Own-child               30161 non-null  uint8
#  35  relationship_ Unmarried               30161 non-null  uint8
#  36  relationship_ Wife                    30161 non-null  uint8
#  37  race_ Asian-Pac-Islander              30161 non-null  uint8
#  38  race_ Black                           30161 non-null  uint8
#  39  race_ Other                           30161 non-null  uint8
#  40  race_ White                           30161 non-null  uint8
#  41  native_ Canada                        30161 non-null  uint8
#  42  native_ China                         30161 non-null  uint8
#  43  native_ Columbia                      30161 non-null  uint8
#  44  native_ Cuba                          30161 non-null  uint8
#  45  native_ Dominican-Republic            30161 non-null  uint8
#  46  native_ Ecuador                       30161 non-null  uint8
#  47  native_ El-Salvador                   30161 non-null  uint8
#  48  native_ England                       30161 non-null  uint8
#  49  native_ France                        30161 non-null  uint8
#  50  native_ Germany                       30161 non-null  uint8
#  51  native_ Greece                        30161 non-null  uint8
#  52  native_ Guatemala                     30161 non-null  uint8
#  53  native_ Haiti                         30161 non-null  uint8
#  54  native_ Honduras                      30161 non-null  uint8
#  55  native_ Hong                          30161 non-null  uint8
#  56  native_ Hungary                       30161 non-null  uint8
#  57  native_ India                         30161 non-null  uint8
#  58  native_ Iran                          30161 non-null  uint8
#  59  native_ Ireland                       30161 non-null  uint8
#  60  native_ Italy                         30161 non-null  uint8
#  61  native_ Jamaica                       30161 non-null  uint8
#  62  native_ Japan                         30161 non-null  uint8
#  63  native_ Laos                          30161 non-null  uint8
#  64  native_ Mexico                        30161 non-null  uint8
#  65  native_ Nicaragua                     30161 non-null  uint8
#  66  native_ Outlying-US(Guam-USVI-etc)    30161 non-null  uint8
#  67  native_ Peru                          30161 non-null  uint8
#  68  native_ Philippines                   30161 non-null  uint8
#  69  native_ Poland                        30161 non-null  uint8
#  70  native_ Portugal                      30161 non-null  uint8
#  71  native_ Puerto-Rico                   30161 non-null  uint8
#  72  native_ Scotland                      30161 non-null  uint8
#  73  native_ South                         30161 non-null  uint8
#  74  native_ Taiwan                        30161 non-null  uint8
#  75  native_ Thailand                      30161 non-null  uint8
#  76  native_ Trinadad&Tobago               30161 non-null  uint8
#  77  native_ United-States                 30161 non-null  uint8
#  78  native_ Vietnam                       30161 non-null  uint8
#  79  native_ Yugoslavia                    30161 non-null  uint8
# dtypes: int64(7), uint8(73)
# memory usage: 3.7 MB

# %%
sns.set(rc={'figure.figsize':(20,12)})
sns.heatmap(train_data.corr())

# %%
# Checking if the data is balanced:
plt.rcParams["figure.figsize"] = (5,5)
data["Salary"].value_counts().plot.bar()

# %% [markdown]
# ##### Observation: we can see that the data is imbalanced as there are more observations of salary less than 50K

# %%
# diciding the data to x and y:
x_train_df = train_data.loc[:, train_data.columns != "Salary"]
y_train_df = train_data.loc[:, train_data.columns == "Salary"]
x_test_df = test_data.loc[:, test_data.columns != "Salary"]
y_test_df = test_data.loc[:, test_data.columns == "Salary"]

# %%
x_train = x_train_df.values
y_train = y_train_df.values.flatten()
x_test= x_test_df.values
y_test = y_test_df.values.flatten()

# %%
# Standardizing the data:
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# #### Using PCA to reduce the dimensions:

# %%
pca = PCA(n_components = 80)
pca_values = pca.fit_transform(train_data) 
var = pca.explained_variance_ratio_
var1 = np.cumsum(np.round(var,decimals = 4)*100)
var1
# Out:
# array([ 99.7, 100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. ,
#        100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. ,
#        100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. ,
#        100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. ,
#        100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. ,
#        100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. ,
#        100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. ,
#        100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. ,
#        100. , 100. , 100. , 100. , 100. , 100. , 100. , 100. ])

# %% [markdown]
# ###### We can see that the first 2 columns of PCA values have retained the whole 100% information. So we will use the first 2 column in our model

# %%
x_train_df = pd.concat([pd.DataFrame(pca_values[:,0:2],columns=['pc1','pc2'])], axis = 1)
x_train_df
# Out:
#                 pc1        pc2
# 0       1082.110002 -86.393704
# 1      -1091.888510 -90.247064
# 2      -1091.886889 -90.229833
# 3      -1091.884837 -90.200091
# 4      -1091.888132 -90.248119
# ...             ...        ...
# 30156  -1091.888579 -90.253953
# 30157  -1091.886585 -90.225445
# 30158  -1091.884049 -90.188935
# 30159  -1091.891769 -90.295393
# 30160  13932.091479 -63.718837
#
# [30161 rows x 2 columns]

# %%
pca_values_test = pca.fit_transform(test_data) 
var2 = pca.explained_variance_ratio_
var3 = np.cumsum(np.round(var,decimals = 4)*100)
x_test_df = pd.concat([pd.DataFrame(pca_values_test[:,0:2],columns=['pc1','pc2'])], axis = 1)
x_test_df
# Out:
#                pc1        pc2
# 0     -1120.152031 -90.960547
# 1     -1120.148736 -90.915300
# 2     -1120.151375 -90.951318
# 3      6567.839639 -77.964009
# 4     -1120.152259 -90.961205
# ...            ...        ...
# 15055 -1120.150668 -90.941152
# 15056 -1120.150412 -90.936390
# 15057 -1120.148557 -90.912983
# 15058  4334.842972 -81.725878
# 15059 -1120.147533 -90.900697
#
# [15060 rows x 2 columns]

# %%
x_train = x_train_df.values
x_test= x_test_df.values
y_test.shape
# Out:
# (15060,)

# %% [markdown]
# ### Building the model:

# %%
# Getting 5 random values for gamma and c
def random_parameters():
    from random import uniform
    gamma = []
    c = []
    for i in range(5):
        gamma.append((round(uniform(0,50),3)))
        c.append((round(uniform(0,15),3)))
    return gamma , c

# %% [markdown]
# #### Hyperparameter tuning:

# %% [markdown]
# ##### (this will take up a lot of resources on the machine)

# %%
# This line will take some time to run
gamma, c = random_parameters()
clf = SVC()
param_grid = [{'kernel':['rbf'],'gamma':gamma,'C':c }]
gsv = GridSearchCV(clf,param_grid,cv=2)
gsv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=2, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'C': [14.351, 6.342, 14.843, 9.824, 0.712],
#                           'gamma': [1.382, 46.367, 28.08, 29.171, 11.236],
#                           'kernel': ['rbf']}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Best parameters
gsv.best_params_ , gsv.best_score_
# Out:
# ({'C': 14.351, 'gamma': 46.367, 'kernel': 'rbf'}, 0.8253373647906961)

# %%
clf = SVC(C= gsv.best_params_['C'], gamma = gsv.best_params_["gamma"], kernel="rbf")
clf.fit(x_train , y_train)
y_pred = clf.predict(x_test)
acc = accuracy_score(y_test, y_pred) * 100
print(f"Accuracy: {round(acc,2)}%")
# Out:
# Accuracy: 75.43%

# %%
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))
cm
# Out:
#        0  1
# 0  11360  0
# 1   3700  0
